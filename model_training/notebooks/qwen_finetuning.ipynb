# %%
import os
os.environ["HF_HOME"] = "/scratch/sampath.ki/hf"

# %%
from tqdm import tqdm

import pandas as pd
from transformers import AutoModelForCausalLM, AutoTokenizer

tqdm.pandas()

# %%
df = pd.read_csv("dataset.csv")
df.dropna(inplace=True)
df.head()
# Out:
#                                             question  \
# 0     Who teaches Fundamentals of Complexity Theory?
# 1  What professor instructs Fundamentals of Compl...
# 2  Which instructor is assigned to Fundamentals o...
# 3  Who is the lecturer for Fundamentals of Comple...
# 4  Fundamentals of Complexity Theory: who is the ...
#
#                                              context  \
# 0  Course Information\nComplexity Theory  CS7805 ...
# 1  Course Information\nComplexity Theory  CS7805 ...
# 2  Course Information\nComplexity Theory  CS7805 ...
# 3  Course Information\nComplexity Theory  CS7805 ...
# 4  Course Information\nComplexity Theory  CS7805 ...
#
#                                             response
# 0  Jamieson Lindsay teaches Fundamentals of Compl...
# 1  Professor Jamieson Lindsay instructs Fundament...
# 2  Jamieson Lindsay teaches Fundamentals of Compl...
# 3  The lecturer for Fundamentals of Complexity Th...
# 4  The professor for Fundamentals of Complexity T...

# %%
model_name = "Qwen/Qwen2.5-1.5B-Instruct"

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto",
    trust_remote_code=True
)

tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def get_query(row):
    system_prompt = """
    You are Course Compass, a chatbot dedicated to assisting Northeastern University graduate students with course registration each semester. You have access to the latest information on available graduate courses, faculty profiles, and summarized student feedback from previous semesters.
    
    Your goals are:
    
    1. To provide accurate, up-to-date information without speculating. If you lack information about a course or question, clearly communicate that to the student.
    2. To maintain a positive, professional tone. If past student feedback includes criticism, you should still respond diplomatically, focusing on constructive or neutral aspects.
    3. To be concise and relevant in your responses, helping students make informed decisions about their course choices.
    
    Avoid negative or speculative responses, and prioritize factual information over assumption.
    
    Answer the questions comprehensively using the reviews from the context by summarizing them to help the student.
    """
        
    max_context_tokens = int(15000 * 0.6)
    context_tokens = tokenizer(row["context"], truncation=True, max_length=max_context_tokens, return_tensors="pt")
    truncated_context = tokenizer.decode(context_tokens["input_ids"][0], skip_special_tokens=True)
    
    prompt = f"""
    Context:
    {truncated_context}
    
    Query:
    {row["question"]}
    
    Answer the query comprehensively using the reviews from the context by summarizing them to help the student.
    """
    
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": prompt}
    ]
    
    text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    return text

# %%
df["query"] = df.progress_apply(get_query, axis=1)
# Out:
# 100%|██████████| 432/432 [00:18<00:00, 22.99it/s]

# %%
def generate_responses(text: str) -> str:
    model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

    generated_ids = model.generate(
        **model_inputs,
        max_new_tokens=512
    )
    generated_ids = [
        output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
    ]
    
    gen_response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

    return gen_response

# %%
# random_df = df.sample(frac=0.1)

random_df["gen_responses"] = random_df["query"].progress_apply(generate_responses)
# Out:
# 100%|██████████| 43/43 [07:51<00:00, 10.96s/it]

# %%
import evaluate

# Load the ROUGE metric
rouge = evaluate.load("rouge")

# Calculate ROUGE scores for all examples in the DataFrame
results = rouge.compute(
    predictions=random_df['gen_responses'].tolist(),
    references=random_df['response'].tolist()
)

results
# Out:
# {'rouge1': 0.3064992875142799,
#  'rouge2': 0.08405681766996795,
#  'rougeL': 0.18099603013904592,
#  'rougeLsum': 0.22086549470472072}

# %%
import torch
from transformers import TrainingArguments, Trainer
from datasets import load_dataset
from peft import LoraConfig, get_peft_model
from datasets import Dataset

# %%
df.loc[0]

# %%
# def tokenize_function(examples):
#     # Tokenize the query (prompt) and response (target)
#     model_inputs = tokenizer(
#         examples["query"],
#         padding="max_length",
#         truncation=True,
#         max_length=4096,  # Adjust max_length as needed
#     )
#     labels = tokenizer(
#         examples["response"],
#         padding="max_length",
#         truncation=True,
#         max_length=4096,
#     )["input_ids"]

#     # Shift labels for causal language modeling
#     model_inputs["labels"] = labels

#     return model_inputs

def preprocess_function(examples):
    inputs = [f"{prompt}\n" for prompt in examples["query"]]
    targets = [f"{completion}\n" for completion in examples["response"]]
    model_inputs = tokenizer(inputs, max_length=512, truncation=True, padding="max_length")
    labels = tokenizer(targets, max_length=512, truncation=True, padding="max_length")
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

dataset = Dataset.from_pandas(df)
tokenized_dataset = dataset.train_test_split(test_size=0.1)
tokenized_dataset = tokenized_dataset.map(preprocess_function, batched=True, remove_columns=dataset.column_names)
# Out:
# Map:   0%|          | 0/388 [00:00<?, ? examples/s]
# Map:   0%|          | 0/44 [00:00<?, ? examples/s]

# %%
tokenized_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 388
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 44
#     })
# })

# %%
lora_config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)
model = get_peft_model(model, lora_config)

# %%
training_args = TrainingArguments(
    output_dir="./results",
    num_train_epochs=1,
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=10,
    evaluation_strategy="steps",
    eval_steps=10,
    save_strategy="steps",
    save_steps=0,
    learning_rate=1e-4,
    fp16=True,
    gradient_checkpointing=True,
    gradient_accumulation_steps=4,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["test"],
    tokenizer=tokenizer,
)
trainer.train()
# Out:
# /home/sampath.ki/emnlp/conda_env/lib/python3.10/site-packages/transformers/training_args.py:1474: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Detected kernel version 3.10.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# /home/sampath.ki/emnlp/conda_env/lib/python3.10/site-packages/torch/utils/checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='97' max='97' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [97/97 02:19, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>14.873800</td>
#       <td>14.873831</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>14.832300</td>
#       <td>14.830644</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>14.741800</td>
#       <td>14.742779</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>14.664400</td>
#       <td>14.609572</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>14.570300</td>
#       <td>14.414749</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>14.229300</td>
#       <td>14.125297</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>13.867500</td>
#       <td>13.694042</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>13.420600</td>
#       <td>13.061489</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>12.721400</td>
#       <td>12.237857</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=97, training_loss=14.044264881881242, metrics={'train_runtime': 141.3474, 'train_samples_per_second': 2.745, 'train_steps_per_second': 0.686, 'total_flos': 1563140800118784.0, 'train_loss': 14.044264881881242, 'epoch': 1.0})

# %%
access_token = "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"

# %%
model.push_to_hub("qwen-finetuned-model")
tokenizer.push_to_hub("qwen-finetuned-model")

# %%
trainer.save_model("./fine_tuned_qwen")
# Out:
# /home/sampath.ki/emnlp/conda_env/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
type(model)

# %%
from peft import PeftModel    
from transformers import AutoModelForCausalLM

adapters_name = "./fine_tuned_qwen"

print(f"Starting to load the model {model_name} into memory")

m = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)
m = PeftModel.from_pretrained(m, adapters_name)
m = m.merge_and_unload()
# Out:
# Starting to load the model Qwen/Qwen2.5-1.5B-Instruct into memory

# %%
# from peft import AutoPeftModelForCausalLM

# fine_tuned_model = AutoModelForCausalLM.from_pretrained("./fine_tuned_qwen", trust_remote_code=True)
fine_tuned_tokenizer = AutoTokenizer.from_pretrained("./fine_tuned_qwen", trust_remote_code=True)

def generate_response(prompt):
    inputs = fine_tuned_tokenizer(prompt, return_tensors="pt").to(model.device)
    outputs = m.generate(**inputs, max_new_tokens=256)
    return fine_tuned_tokenizer.decode(outputs[0], skip_special_tokens=True)
    
# Example usage
prompt = df["query"][0]
response = generate_response(prompt)
print(f"Response: {response}")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Response: system
#
#     You are Course Compass, a chatbot dedicated to assisting Northeastern University graduate students with course registration each semester. You have access to the latest information on available graduate courses, faculty profiles, and summarized student feedback from previous semesters.
#
#     Your goals are:
#
#     1. To provide accurate, up-to-date information without speculating. If you lack information about a course or question, clearly communicate that to the student.
#     2. To maintain a positive, professional tone. If past student feedback includes criticism, you should still respond diplomatically, focusing on constructive or neutral aspects.
#     3. To be concise and relevant in your responses, helping students make informed decisions about their course choices.
#
#     Avoid negative or speculative responses, and prioritize factual information over assumption.
#
#     Answer the questions comprehensively using the reviews from the context by summarizing them to help the student.
#
# user
#
#     Context:
#     Course Information
# Complexity Theory  CS7805  Jamieson Lindsay  Portland Maine  Covers core topics in computational complexity including NPcompleteness time and space complexity polynomial hierarchy circuit complexity probabilistic computation interactive proofs and hardness of approximation Moves to more advanced topics that may include lower bounds pseudorandomness cryptography and communication complexity  Spring 2025  monday
# Review Information
# Q1
# nice in whole field
#  Q1
# lindsay is a fantastic lecturer i always felt welcome to ask questions which i did a lot i imagine 5001 is a tough course to lecture since folks seem to believe it is either so basic that the professor dont need to study or so unsure of their abilities that the professor dont believe the professor can learn these things lindsay balances those two hemispheres very well demonstrating why foundations are so important and elevating the less confident folks among us i was so impressed by the progress all of us made this semester
#  Q1
# the logic is clear classes are interactive
#  Q1
# the course contains the knowledge of python that a beginner needs to master
#  Q1
# very clear and organized and very fair grading
#  Q1
# lindsay was exceptionally organized and prepared for class the professor had a clear plan in mind and used the time efficiently to achieve our learning goals the professor also did a great job keeping the tas on track with grading assignments in a timely manner the professor class time was a good mix of active and passive learning styles
#  Q1
# instructor made the concept as easy as possible to explain to us
#  Q1
# this course can give people who are new to programming languages a good foundation the strengths of this instructor are enthusiasm and clear thinking
#  Q2
# all nice
#  Q2
# general organizational things like making sure the canvas pages between cs5001 and cs5003 were better integrated with each other along with gradescope sometimes gradescope and canvas would have contradictory information re due dates and point values which was a little bit annoying but generally the point was put across well enough
#  Q2
# there could be less text writing assignments and more programming exercises
#  Q2
# just an awful lot of hours of work not all of that time was for increased learning instructor very open and receptive to feedback on the course not all instructional feedback timely
#  Q2
# the tas in this course did an excellent job as well i would like to hear more from the tas in the form of comments on our assignments for example if the professor noticed we did something that wouldnt lose us points but was very inefficient the professor could let us know in the form of a comment even more importantly if the professor notice we did something extra clever the professor should tell us so we know when we did something well and can reuse those skills in the future
#  Q2
# homework instruction could be more specific especially at the beginning of the semester
#  Q2
# the instructor could impart more content and provide additional examples during the class
#  Q4
# nice
#  Q4
# gradescope and canvas were often out of sync with each other with regards to deadlines and grade values as a result instructionstimelines were sometimes unclear
#  Q4
# the online course environment is very good it helps people like me who are new to english to review the lessons and participate in group discussions as well
#  Q4
# online courses help every student get into the swing of things quickly while saving time on the road
#  Q4
# good overall
#  Q4
# i think the experience of online course is good     student selfassessment of their effort to achieve course outcomes 7 comments
#  Q5
# maybe study more bcz there are some topics that courses will not covered but we often use in problemsolving
#  Q5
# time management skills and better planning out of studyhomework times i was constantly scrambling to have things turned in on time and had i simply stuck to a schedule of my own study time i wouldnt have been nearly as stressed and would have done better academically
#  Q5
# maybe do some prep before class
#  Q5
# lindsay assigned some homework assignments that had very little relevance to knowledge enhancement such as the synthesis assignment and i could have put more of the time i spent on this book into learning other knowledge points
#  Q5
# prepare for the actual number of hours it would take instead of the hours that admissions said it would take
#  Q5
# i would consult with ta more often at the beginning of the course
#  Q5
# i learned more knowledge and reviewed it in time positive neutral negative 0 25 50 75 100 please comment on your experience of the online course 83 undefined 17 undefined 0 u 0 u 0 u percent of sentiment sentiment joy fear sadness anger 000 025 050 075 100 074 074 074 078 078 078 003 003 003 019 019 019 003 003 003 sentiment score
#  unknown
# its good stuff there
#  unknown
# publish the rules for grading assignments to fair each students grading criteria
#  unknown
# very clear communicator and very organized very clear expectations reasonable deadlines
#  unknown
# i appreciated that lindsay took the time to grade our synthesis assignments herself grading those assignments kept the professor in touch with how well we were learning the material and it gave us an opportunity to hear from the professor individually about anything we may have misunderstood
#  unknown
# the instructor is good at clear communication ensuring that instructions and explanations are easily understood by all students regardless of their background or prior knowledge questions to assess students online experience 6 comments
#  unknown
# none
#  unknown
# none
#
#
#
# Course Information
# Complexity Theory  CS7805  Jamieson Lindsay  Portland Maine  Covers core topics in computational complexity including NPcompleteness time and space complexity polynomial hierarchy circuit complexity probabilistic computation interactive proofs and hardness of approximation Moves to more advanced topics that may include lower bounds pseudorandomness cryptography and communication complexity  Spring 2025  monday
# Review Information
# Q1
# presenting material in a way that was easier to understand
#  Q1
# lindsay provided many different types of assignments all of which were appropriately challenging and helped me understand the material better the lectures were concise and covered important topics i appreciated the opportunities to do practice problems in class lindsay also did a great job of emphasizing cultural diversity in computing which i found interesting
#  Q1
# lindsay clearly enjoys teaching the course and cared for the quality of the class the professor was also very good at being accommodating to students at different experience levels the professor kept both students with 0 coding experience and students with a solid coding background engaged throughout the course
#  Q1
# lindsay communicates clearly and effectively in class the professor structures the professor lectures well and the course work minus the quizzes helps to reinforce the skills learned each week i think the combination of in class learning and outsideofclass assignments helped to build a solid foundational knowledge of the material in addition to this i was really appreciative of how easy it was to get support from lindsay outside of class hours the professor responds to emails and teams chats very quickly and from my experience always managed to help me understand and solve whatever blocker i was facing in about 2 or 3 sentences when i was struggling early on the professor was more than happy to schedule a 1x1 with me where we discussed the class the root of my struggles and some plans to help moving forward
#  Q1
# i appreciated lindsays promptness in responding to questions and providing feedback the professor provided all of the necessary resources for students to succeed in this course
#  Q2
# ensure that some of the tickytacky portions dont get in the way of learning the content ie coding practices
#  Q2
# more focused programming problems instead of online quizzes
#  Q2
# reduce the amount of work  emphasize the most important assignments more feedback on assignments give time to work on practice problems individually before partnering up
#  Q2
# there were two quality of life improvements that lindsay could change to make the course better and avoid confusion in certain areas 1 this was a fall semester course but some of our assignment pdfs and course materials had the prior spring semesters due dates listed please update the docs for the next class so it is clear for the professor when things are due 2 please standardize the time of due dates in gradescope  we had some assignments that would be due at 1159 pm and others that were due at 1200 am please stick to one so it is clear if assignments are due at end of date listed or at end of day prior for 1200 am case
#  Q2
# i sometimes found some of the questions in the quizzescoding practicesprojects to be either vague or confusing i think that another pass with a discerning eye for clarity could help to sure this up pretty quickly
#  Q4
# positive neutral negative 0 25 50 75 100 please comment on your experience of the online course 60 undefined 0 undefined 0 undefined 0 undefined 40 undefined percent of sentiment
#  Q4
# there were some aspects of the online portion that could use another look for polish but overall the content and usefulness was there
#  Q4
# a lot of the course was selfdriven anyway so it translated well to a remote academic experience
#  Q4
# having grades assignments and materials on 4 different platforms gradescope 5003 and 5001 ethics was confusing at times online communities were generally lacking much participation
#  Q4
# for the majority of the class i attended inperson lectures but during the occasional week i was sick i would login to the zoom lectures these were setup well so i could see and hear the profs materials so attending virtual lectures never harmed the learning process the organization of the course materials in canvas was great for the weekly topics
#  Q4
# canvas is garbage      student selfassessment of their effort to achieve course outcomes 5 comments
#  Q5
# stay on top of my work
#  Q5
# i was very busy this semester but normally i wouldve spent more time physically in the class
#  Q5
# reached out to the dr lindsay and tas more frequently
#  Q5
# i could have reviewed some of the weekly online materials prior to the class so that i was ready for the recitation projects as soon as the professor were released but with the workload it was hard to stay as ahead as i would have liked
#  Q5
# it would have been really helpful if the admissions department was able to get my student account setup properly in a timely fashion sentiment joy fear sadness anger 000 025 050 075 100 012 012 012 047 047 047 004 004 004 030 030 030 004 004 004 sentiment score
#  unknown
# i would ask for more involvement with breakout rooms a lot of the time it felt like i was the only one working and i wouldve profited from being more engaged at that time
#  unknown
# overall lindsay did a good job at facilitating an inclusive learning environment
#  unknown
# always willing to help shows a propensity for meeting students where the professor are and helping to bridge the gap so the professor can get where the professor need to be
#  unknown
# lindsay in an exceptional instructor in many ways the professor made the content of this course accessible i feel that i have a solid understanding of computer science fundamentals because of her one thing that i would like to highlight about lindsay is that the professor chose to showcase the accomplishments of leaders in computer science who are also members of minorities i deeply appreciate the professor efforts to set the premise that computer science is a field for everyone not just straight white men questions to assess students online experience 5 comments
#
#
#
# Course Information
# Complexity Theory  CS7805  Jamieson Lindsay  Portland Maine  Covers core topics in computational complexity including NPcompleteness time and space complexity polynomial hierarchy circuit complexity probabilistic computation interactive proofs and hardness of approximation Moves to more advanced topics that may include lower bounds pseudorandomness cryptography and communication complexity  Spring 2025  monday
# Review Information
# Q1
# lindsey definitely enjoys what the professor teaches and does a good job providing additional computer related information in an effort to shine a light on the unseen members of the coding community being remote i did not interact with the professor directly much but the professor presents as approachable and able to direct you to an answer without giving you the answer directly
#  Q1
# lindsay expressed that the professor cares deeply about teaching and the professor understands the conditions under which adults can learn effectively the class meetings were structured to support student engagement and the assignments reinforced the key concepts
#  Q1
# undertsanding organization in class activities responsiveness
#  Q1
#  projects and assignments supported each modules material 2 instructor explained things clearly in class provided inclass problems to discuss that were helpful for learning
#  Q1
# the course covered a lot of material and the instructor was very knowledgeable about everything we reviewed
#  Q1
# availability for questions and explanation of complex topics to beginners
#  Q1
# lindsay does an excellent job of making computer science relatable to everyday life and sharing just enough information to impart a strong understanding of foundational concepts without getting bogged down in minutia
#  Q1
# the instructor was excited about the material and prepared the material in lessons well videos of the lecture as well as additional review videos were included in the material for the course which was very helpful when completing assignments during the lectures it was great to be given time to try out what we were learning in small groups
#  Q2
# where this is my first course with roux im not sure i get the feeling that the structure of the course is mostly predetermined i dont have a read on how much was within lindseys control and how much is the way the align program wants the course to run this is not a recommendation for the professor but a recommendation for the align program or roux the pace of this course is very rapid and it should not be offered on mondays i felt the number of classes that we missed because all academic holidays fall on mondays was very hindering
#  Q2
# some of the documentation on canvas is outdated or inaccurate for the current iterations of the assignments it might be helpful to revise those documents so that the professor match all expectations
#  Q2
# i think linsday had clear expectations which is very difficult to do as a teacher but there is always room to improve in terms of being very clear about what is expected on assignments especially projects with the rubrics the professor was incredibly responsive with questions asked about this so i dont see it as a weakness rather a strength
#  Q2
# make part of the coding practice optional having almost 10 for every module is a lot of work on top of the projects and synthesis assignments
#  Q2
# the in class group assignmentsexercises should be explained better prior to starting them it would be helpful if the online modules were available earlier in the week or all at once so i could go through the professor at my own pace
#  Q2
# the two things i wish i knew at the start of the course are related to the expectations on the syntheses first was that the suggested synthesis structure follows the online prerecorded lectures rather than the inclass lectures knowing this at the start of the semester would have made my first synthesis significantly easier to write i might be an outlier but the only time i turned to the prerecorded lectures was as a reference when creating the synthesis second is the expectation regarding originality of examples exercises and solutions there are only so many ways to write some of the basic examples and it only came up later in the semester that it was more important to use a correct example rather than an original one for the simplest structures
#  Q2
#  there were times during the recitation when i would get started on the project and then get lost it would be helpful to have the instructor there for more of the class time to ask questions if we got stuck
#  Q4
# i think that lindsay did a good job providing opportunities for us to be engaged virtually a good portion of my disconnect came from the setup of the course overall the union between the video modules and the course were obvious but i got to a point where i wasnt able to watch the module before the lecture this meant i personally didnt get as much from the lecture times at the time it was occurring having the recordings to go back to after i understood the material more was helpful the online interactions were not for lack of resources and were more due to the way i interact with other people online as well as my classmates use or lack thereof of the different avenues provided
#  Q4
# i definitely preferred attending class in person but being able to join online when necessary was super helpful
#  Q4
# there were certain times when online information was not updated as quickly as the other classes or was forgotten which i think is understandble given the dual canvas set up which i think puts a higher stress of organization on the professor
#  Q4
# i felt the online course modules were extremely helpful and served as the basis for most explanations of topics
#  Q4
# it was well structured and helpful for staying on top of the course requirements throughout the semester
#  Q4
# i was an inperson student for the whole semester so my only online course interactions were the prerecorded lectures and homework submissions i understand the need for standardization but found the prerecorded lectures to be the most time consuming and lowest return on my time investment resource in the class     student selfassessment of their effort to achieve course outcomes 5 comments
#  Q5
# im not sure getting ahead of the videos would have helped so i could have had actual questions come class time instead of being a week or more behind
#  Q5
# consistently reviewing modules
#  Q5
# watch the online course videos prior to attending class
#  Q5
# time management was a significant struggle on this course the assignments arent hard which makes the professor seem faster to work through than the professor actually are i noticed late in the semester that the synthesis assignments follow the recorded lectures not the in person lectures noticing this earlier would have made writing my syntheses much easier
#  Q5
# i could have used more time management skills to give myself time needed to complete the assignments positive neutral negative 0 25 50 75 100 please comment on your experience of the online course 83 undefined 0 undefined 0 undefined 0 undefined 17 undefined percent of sentiment sentiment joy fear sadness anger 000 025 050 075 100 049 049 049 047 047 047 005 005 005 028 028 028 006 006 006 sentiment score
#  unknown
# i think the professor did well for a hybrid class it is difficult to be remote and have a group in class which is a challenge were all getting used to in our walks of life
#  unknown
# lindsay did an excellent job of facilitating inclusive learning it felt to me like all students were encouraged to be a part of the conversation and to ask for support i appreciated seeing so many inclusive examples of computer scientists in each lecture
#  unknown
# as i said above lindsay was responsive and organized and had clear expectations and structrue for the course the professor was friendly and engaging
#  unknown
# the instructor focused on having the students work in pairs or groups and that has its place but not all of the assignments required or necessitated as much time as we were given to complete
#  unknown
# dr lindsay is very conscientious regarding the facilitation of inclusive learning
#  unknown
# the instructor made this course very inclusive especially considering this is the first class in the cs align program as someone without any computer science experience this class made me feel challenged but also empowered to be able to do something i didnt know i could do going into this course i felt nervous and people around me told me that i would not be successful with learning something so different from what i do now from the very first moments of class lindsay made the classroom welcoming and i felt that my thoughts were valued even without previous experience in this course we also learned about the many women who have had successful careers as computer scientists which was very inspiring and made me feel that i could complete this course even when it was hard i am thankful to have had a teacher that not only believed in me but also showed me how having a background in teaching and being a woman can be valuable assets in this field questions to assess students online experience 6 comments
#
#
#
# Course Information
# Complexity Theory  CS7805  Jamieson Lindsay  Portland Maine  Covers core topics in computational complexity including NPcompleteness time and space complexity polynomial hierarchy circuit complexity probabilistic computation interactive proofs and hardness of approximation Moves to more advanced topics that may include lower bounds pseudorandomness cryptography and communication complexity  Spring 2025  monday
# Review Information
# Q1
# lindsey definitely enjoys what the professor teaches and does a good job providing additional computer related information in an effort to shine a light on the unseen members of the coding community being remote i did not interact with the professor directly much but the professor presents as approachable and able to direct you to an answer without giving you the answer directly
#  Q1
# lindsay expressed that the professor cares deeply about teaching and the professor understands the conditions under which adults can learn effectively the class meetings were structured to support student engagement and the assignments reinforced the key concepts
#  Q1
# undertsanding organization in class activities responsiveness
#  Q1
#  projects and assignments supported each modules material 2 instructor explained things clearly in class provided inclass problems to discuss that were helpful for learning
#  Q1
# the course covered a lot of material and the instructor was very knowledgeable about everything we reviewed
#  Q1
# availability for questions and explanation of complex topics to beginners
#  Q1
# lindsay does an excellent job of making computer science relatable to everyday life and sharing just enough information to impart a strong understanding of foundational concepts without getting bogged down in minutia
#  Q1
# the instructor was excited about the material and prepared the material in lessons well videos of the lecture as well as additional review videos were included in the material for the course which was very helpful when completing assignments during the lectures it was great to be given time to try out what we were learning in small groups
#  Q2
# where this is my first course with roux im not sure i get the feeling that the structure of the course is mostly predetermined i dont have a read on how much was within lindseys control and how much is the way the align program wants the course to run this is not a recommendation for the professor but a recommendation for the align program or roux the pace of this course is very rapid and it should not be offered on mondays i felt the number of classes that we missed because all academic holidays fall on mondays was very hindering
#  Q2
# some of the documentation on canvas is outdated or inaccurate for the current iterations of the assignments it might be helpful to revise those documents so that the professor match all expectations
#  Q2
# i think linsday had clear expectations which is very difficult to do as a teacher but there is always room to improve in terms of being very clear about what is expected on assignments especially projects with the rubrics the professor was incredibly responsive with questions asked about this so i dont see it as a weakness rather a strength
#  Q2
# make part of the coding practice optional having almost 10 for every module is a lot of work on top of the projects and synthesis assignments
#  Q2
# the in class group assignmentsexercises should be explained better prior to starting them it would be helpful if the online modules were available earlier in the week or all at once so i could go through the professor at my own pace
#  Q2
# the two things i wish i knew at the start of the course are related to the expectations on the syntheses first was that the suggested synthesis structure follows the online prerecorded lectures rather than the inclass lectures knowing this at the start of the semester would have made my first synthesis significantly easier to write i might be an outlier but the only time i turned to the prerecorded lectures was as a reference when creating the synthesis second is the expectation regarding originality of examples exercises and solutions there are only so many ways to write some of the basic examples and it only came up later in the semester that it was more important to use a correct example rather than an original one for the simplest structures
#  Q2
#  there were times during the recitation when i would get started on the project and then get lost it would be helpful to have the instructor there for more of the class time to ask questions if we got stuck
#  Q4
# i think that lindsay did a good job providing opportunities for us to be engaged virtually a good portion of my disconnect came from the setup of the course overall the union between the video modules and the course were obvious but i got to a point where i wasnt able to watch the module before the lecture this meant i personally didnt get as much from the lecture times at the time it was occurring having the recordings to go back to after i understood the material more was helpful the online interactions were not for lack of resources and were more due to the way i interact with other people online as well as my classmates use or lack thereof of the different avenues provided
#  Q4
# i definitely preferred attending class in person but being able to join online when necessary was super helpful
#  Q4
# there were certain times when online information was not updated as quickly as the other classes or was forgotten which i think is understandble given the dual canvas set up which i think puts a higher stress of organization on the professor
#  Q4
# i felt the online course modules were extremely helpful and served as the basis for most explanations of topics
#  Q4
# it was well structured and helpful for staying on top of the course requirements throughout the semester
#  Q4
# i was an inperson student for the whole semester so my only online course interactions were the prerecorded lectures and homework submissions i understand the need for standardization but found the prerecorded lectures to be the most time consuming and lowest return on my time investment resource in the class     student selfassessment of their effort to achieve course outcomes 5 comments
#  Q5
# im not sure getting ahead of the videos would have helped so i could have had actual questions come class time instead of being a week or more behind
#  Q5
# consistently reviewing modules
#  Q5
# watch the online course videos prior to attending class
#  Q5
# time management was a significant struggle on this course the assignments arent hard which makes the professor seem faster to work through than the professor actually are i noticed late in the semester that the synthesis assignments follow the recorded lectures not the in person lectures noticing this earlier would have made writing my syntheses much easier
#  Q5
# i could have used more time management skills to give myself time needed to complete the assignments positive neutral negative 0 25 50 75 100 please comment on your experience of the online course 83 undefined 0 undefined 0 undefined 0 undefined 17 undefined percent of sentiment sentiment joy fear sadness anger 000 025 050 075 100 049 049 049 047 047 047 005 005 005 028 028 028 006 006 006 sentiment score
#  unknown
# i think the professor did well for a hybrid class it is difficult to be remote and have a group in class which is a challenge were all getting used to in our walks of life
#  unknown
# lindsay did an excellent job of facilitating inclusive learning it felt to me like all students were encouraged to be a part of the conversation and to ask for support i appreciated seeing so many inclusive examples of computer scientists in each lecture
#  unknown
# as i said above lindsay was responsive and organized and had clear expectations and structrue for the course the professor was friendly and engaging
#  unknown
# the instructor focused on having the students work in pairs or groups and that has its place but not all of the assignments required or necessitated as much time as we were given to complete
#  unknown
# dr lindsay is very conscientious regarding the facilitation of inclusive learning
#  unknown
# the instructor made this course very inclusive especially considering this is the first class in the cs align program as someone without any computer science experience this class made me feel challenged but also empowered to be able to do something i didnt know i could do going into this course i felt nervous and people around me told me that i would not be successful with learning something so different from what i do now from the very first moments of class lindsay made the classroom welcoming and i felt that my thoughts were valued even without previous experience in this course we also learned about the many women who have had successful careers as computer scientists which was very inspiring and made me feel that i could complete this course even when it was hard i am thankful to have had a teacher that not only believed in me but also showed me how having a background in teaching and being a woman can be valuable assets in this field questions to assess students online experience 6 comments
#
#
#
# Course Information
# Complexity Theory  CS7805  Jamieson Lindsay  Portland Maine  Covers core topics in computational complexity including NPcompleteness time and space complexity polynomial hierarchy circuit complexity probabilistic computation interactive proofs and hardness of approximation Moves to more advanced topics that may include lower bounds pseudorandomness cryptography and communication complexity  Spring 2025  monday
# Review Information
# Q1
# the course was well prepared
#  Q1
# lindsay is nice and a teaching enthusiasm on computer science
#  Q1
# the projects were effective and challenging i got a sense of achievement each time i successfully completed one which made me really enjoy my time in this course
#  Q1
# this course can give people who are new to programming languages a good foundation the strengths of this instructor are enthusiasm and clear thinking
#  Q2
# be a little more specific in your criteria for judging assignmentsassignments that can be resubmitted dont give out grades until right before the deadline
#  Q2
# maybe improve the project guideline like the score evaluate standard bcz sometimes we dont know the detail information about our projects feedback
#  Q2
# the instructor could impart more content and provide additional examples during the class
#  Q4
# very well
#  Q4
# all nice
#  Q4
# i think the experience of online course is good     student selfassessment of their effort to achieve course outcomes 3 comments positive neutral negative 0 25 50 75 100 please comment on your experience of the online course 100 undefined 0 u 0 u 0 u 0 u 0 u 0 u percent of sentiment sentiment joy fear sadness anger 000 025 050 075 100 096 096 096 073 073 073 005 005 005 010 010 010 003 003 003 sentiment score
#  Q5
# do some recap via threaded lessons
#  Q5
# i learned more knowledge and reviewed it in time
#  unknown
# no everything is good and on the right way
#  unknown
# the instructor is good at clear communication ensuring that instructions and explanations are easily understood by all students regardless of their background or prior knowledge questions to assess students online experience 3 comments
#  Q5
# none
#  unknown
# none
#
#
#
# Course Information
# Complexity Theory  CS7805  Jamieson Lindsay  Portland Maine  Covers core topics in computational complexity including NPcompleteness time and space complexity polynomial hierarchy circuit complexity probabilistic computation interactive proofs and hardness of approximation Moves to more advanced topics that may include lower bounds pseudorandomness cryptography and communication complexity  Spring 2025  monday
# Review Information
# Q1
# the projects did help to reinforce the course concepts in interesting ways lottery project  ice cream shoppe were my favorites
#  Q1
# lindsay is great please see below for my thoughts on having to fill out this survey twice
#  Q1
# lindsay seemed to dislike teaching the course and it made for an unpleasant class environment i also felt incredibly discouraged from asking questions after viewing how the professor responded to other students in the class discord in the first class the professor had told us to always reach out if we were stuck on a problem for more than 30 minutes but then the professor would respond to peoples questions in discord with messages like  other students have figured this out and no actual help additionally the autograder was very frustrating at the beginning of the class no parameters for it were taught to us and on my first few assignments i probably wasted like 7 hours just deleting blank lines etc to try to figure out what it wanted from me after i got used to this it was not a problem but it is something that could so easily have been avoided through proper instruction
#  Q1
# lindsay was always in attendance and available to answer questions
#  Q2
# the quality was good there is not much lindsay could do to improve recitation quality for khoury college it felt like there wasnt a full need for a recitation for this class the concepts werent too challenging and by the end of the semester  75 of students either attended recitation from zoom or did not attend it was helpful to have time blocked off each week to work on projectshomework but just thought it would be worth mentioning
#  Q2
# this is not a criticism of the instructor but why do we need to have a second course for the recitation having to jump between two course instances in canvas made things unnecessarily confusing even now as i fill out this survey i cant help but feel like creating a second submission for the recitation is a complete waste of my time
#  Q2
# i fell behind through my own faults but i would say the due dates could be structured differently and if the professor had been it would not have happened and i would have learned more  if the due dates were not structured with the flexibility to put things off until the synthesis due date i would have gotten all of my assignments in on time without being overwhelmed
#  Q4
# the online course experience was good materials were organized logically sometimes the project instructions were less clear than the professor could be but any problems could be worked out with the tas andor lindsay
#  Q4
# canvas is still garbage      positive neutral negative 0 25 50 75 100 please comment on your experience of the online course 33 undefined 0 undefined 0 undefined 0 undefined 67 undefined percent of sentiment sentiment joy fear sadness anger 050 000 050 100 150 025 025 025 042 042 042 005 005 005 027 027 027 004 004 004 sentiment score
#  Q4
# hard to connect with virtual learners and the breakout room experience was always pretty awkward and stilted some people would just not talk at all when you ended up in a breakout room with them would have preferred if the class was more focused on instruction like the modules and not exercises     student selfassessment of their effort to achieve course outcomes 2 comments
#  Q5
# review all weekly course materials prior to recitations but this was challenging w workload
#  Q5
# i was just not a good student in this course the flexibility around assignments not being truly due until the synthesis due dates ruined me for this course because i put the professor off until there was too much work for me to complete in the available time this is completely my own failing
#  unknown
# lindsay good canvas bad
#  unknown
# when the instructor expresses disdain for student questions in the class discord the professor instructed us to join it is hard to imagine an inclusive learning environment being constructed questions to assess students online experience 3 comments
#
#
#
# Course Information
# Complexity Theory  CS7805  Jamieson Lindsay  Portland Maine  Covers core topics in computational complexity including NPcompleteness time and space complexity polynomial hierarchy circuit complexity probabilistic computation interactive proofs and hardness of approximation Moves to more advanced topics that may include lower bounds pseudorandomness cryptography and communication complexity  Spring 2025  monday
# Review Information
# Q1
# the course projects were informative and beneficial although the professor were poorly explained at times the project prompts could have been much more clear
#  Q1
# the projects assigned in the course were very helpful exercises for working through the concepts we covered
#  Q2
# attend the recitation in person
#  Q2
# it would have been helpful to know at the beginning of the semester that the projects in recitation would take significantly longer than the recitation period and would require outofclass time to be dedicated to them the lab instructions could be edited for clarity i know this is reflective of real life but often we spent the first 45 minutes of lab trying to figure out what the assignment was so we would run out of time to work on the lab and ask implementation questions projects 68 and 9 were where i had the most confusion over what the assignment was and what the deliverables were supposed to be having a list of file names and sample output would be helpful
#  Q4
# joining the recitation remotely was definitely helpful from time to time but i preferred the easier communication with my classmates when i attended in person     positive neutral negative 0 25 50 75 100 please comment on your experience of the online course 100 undefined 0 u 0 u 0 u 0 u 0 u 0 u percent of sentiment sentiment joy fear sadness anger 000 025 050 075 100 096 096 096 054 054 054 001 001 001 060 060 060 002 002 002 sentiment score
#  unknown
# the instructor was not available during this class period and only was on zoom for less than 5 minutes before departing this was not helpful as this course is for working professionals we dont always have time to attend office hours it would have been helpful to work through project questions with the instructor in the recitation questions to assess students online experience 1 comments
#
#
#
# Course Information
# Complexity Theory  CS7805  Jamieson Lindsay  Portland Maine  Covers core topics in computational complexity including NPcompleteness time and space complexity polynomial hierarchy circuit complexity probabilistic computation interactive proofs and hardness of approximation Moves to more advanced topics that may include lower bounds pseudorandomness cryptography and communication complexity  Spring 2025  monday
# Review Information
# Q1
# the course projects were informative and beneficial although the professor were poorly explained at times the project prompts could have been much more clear
#  Q1
# the projects assigned in the course were very helpful exercises for working through the concepts we covered
#  Q2
# attend the recitation in person
#  Q2
# it would have been helpful to know at the beginning of the semester that the projects in recitation would take significantly longer than the recitation period and would require outofclass time to be dedicated to them the lab instructions could be edited for clarity i know this is reflective of real life but often we spent the first 45 minutes of lab trying to figure out what the assignment was so we would run out of time to work on the lab and ask implementation questions projects 68 and 9 were where i had the most confusion over what the assignment was and what the deliverables were supposed to be having a list of file names and sample output would be helpful
#  Q4
# joining the recitation remotely was definitely helpful from time to time but i preferred the easier communication with my classmates when i attended in person     positive neutral negative 0 25 50 75 100 please comment on your experience of the online course 100 undefined 0 u 0 u 0 u 0 u 0 u 0 u percent of sentiment sentiment joy fear sadness anger 000 025 050 075 100 096 096 096 054 054 054 001 001 001 060 060 060 002 002 002 sentiment score
#  unknown
# the instructor was not available during this class period and only was on zoom for less than 5 minutes before departing this was not helpful as this course is for working professionals we dont always have time to attend office hours it would have been helpful to work through project questions with the instructor in the recitation questions to assess students online experience 1 comments
#
#
#
#     Query:
#     Who teaches Fundamentals of Complexity Theory?
#
#     Answer the query comprehensively using the reviews from the context by summarizing them to help the student.
#
# assistant
# Based on the reviews, Jamieson Lindsay teaches Fundamentals of Complexity Theory. The reviews indicate that Lindsay is enthusiastic about teaching the course and cares about the quality of the class. He provides additional computer-related information to shine a light on the unseen members of the coding community. The reviews suggest that Lindsay's ability to facilitate inclusive learning and engage students effectively is a strength of his teaching style. Additionally, he covers a lot of material and prepares the material in lessons well, with videos of the lecture and additional review videos included in the material. Overall, the reviews reflect positively on Lindsay's teaching methods and materials.

# %%
random_df["gen_responses1"] = random_df["query"].progress_apply(generate_response)
# Out:
# 100%|██████████| 43/43 [06:34<00:00,  9.17s/it]

# %%
random_df["gen_responses1"] = random_df["gen_responses1"].apply(lambda x: x.split("assistant\n")[-1])

# %%
import evaluate

# Load the ROUGE metric
rouge = evaluate.load("rouge")

# Calculate ROUGE scores for all examples in the DataFrame
results = rouge.compute(
    predictions=random_df['gen_responses1'].tolist(),
    references=random_df['response'].tolist()
)

results
# Out:
# {'rouge1': 0.31417025764891876,
#  'rouge2': 0.0813013179978391,
#  'rougeL': 0.1813838311126142,
#  'rougeLsum': 0.21935332363384488}
